# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Show all output for a cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
import pandas as pd

from src.config import TRANSFORMED_DATA_DIR

features_and_targets = pd.read_parquet(TRANSFORMED_DATA_DIR / "citi_bike_tabular_data.parquet")

# %%
features_and_targets.head()
# Out:
#    ride_count_t-672  ride_count_t-671  ride_count_t-670  ride_count_t-669  \
# 0                 1                 2                 1                 2
# 1                 1                 1                 0                 0
# 2                 0                 0                 0                 0
# 3                 1                 0                 0                 1
# 4                 2                 0                 2                 0
#
#    ride_count_t-668  ride_count_t-667  ride_count_t-666  ride_count_t-665  \
# 0                 0                 0                 1                 0
# 1                 0                 0                 0                 7
# 2                 0                 5                 7                 3
# 3                 0                 0                 5                 4
# 4                 1                 2                 5                 8
#
# ...

# %%
features = features_and_targets.iloc[:, :-1]
targets = features_and_targets["target"]

# %%
features_and_targets['start_station_id'].value_counts()
# Out:
# start_station_id
# 5905.14    338
# 6140.05    338
# 6450.05    338
# Name: count, dtype: int64

# %%
from src.plot_utils import plot_aggregated_time_series

plot_aggregated_time_series(features, targets, row_id=330)
